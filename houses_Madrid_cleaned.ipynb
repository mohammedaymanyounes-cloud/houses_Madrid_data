# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

sns.set()
pd.options.display.float_format='{:,.2f}'.format
pd.options.display.max_rows=None
pd.options.display.max_columns=None

# %%
df=pd.read_csv(r"C:\Users\mohaa\Desktop\houses_Madrid.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
# 5           5  21737                          Piso en venta en geologia
# 6           6  21736             Piso en venta en avenida Real de Pinto
# 7           7  21735                        Piso en venta en San Andrés
# 8           8  21734                          Piso en venta en Butarque
# 9           9  21733           Piso en venta en calle de Martinez Oviol
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid        64.00         60.00        2         1.00
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0        id  sq_mt_built  sq_mt_useful   n_rooms  n_bathrooms  \
# count   21,742.00 21,742.00    21,616.00      8,228.00 21,742.00    21,726.00
# mean    10,870.50 10,871.50       146.92        103.46      3.01         2.09
# std      6,276.52  6,276.52       134.18         88.26      1.51         1.41
# min          0.00      1.00        13.00          1.00      0.00         1.00
# 25%      5,435.25  5,436.25        70.00         59.00      2.00         1.00
# 50%     10,870.50 10,871.50       100.00         79.00      3.00         2.00
# 75%     16,305.75 16,306.75       162.00        113.00      4.00         2.00
# max     21,741.00 21,742.00       999.00        998.00     24.00        16.00
#
#        n_floors  sq_mt_allotment  latitude  longitude  portal  door  \
# count  1,437.00         1,432.00      0.00       0.00    0.00  0.00
# mean       3.13           241.69       NaN        NaN     NaN   NaN
# ...

# %%
df=df.dropna(axis=1,how='all')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    21742 non-null  int64
#  1   id                            21742 non-null  int64
#  2   title                         21742 non-null  object
#  3   subtitle                      21742 non-null  object
#  4   sq_mt_built                   21616 non-null  float64
#  5   sq_mt_useful                  8228 non-null   float64
#  6   n_rooms                       21742 non-null  int64
#  7   n_bathrooms                   21726 non-null  float64
#  8   n_floors                      1437 non-null   float64
#  9   sq_mt_allotment               1432 non-null   float64
#  10  raw_address                   16277 non-null  object
#  11  is_exact_address_hidden       21742 non-null  bool
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample()
# Out:
#        Unnamed: 0     id                                 title  \
# 11079       11079  10663  Piso en venta en calle Ponce de León
#
#               subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 11079  Almagro, Madrid        47.00           NaN        1         1.00
#
#        n_floors  sq_mt_allotment          raw_address  \
# 11079       NaN              NaN  Calle Ponce de León
#
#        is_exact_address_hidden          street_name street_number  \
# 11079                     True  Calle Ponce de León           NaN
#
#                  floor is_floor_under  \
# 11079  Sótano interior           True
#
#                                          neighborhood_id operation  \
# 11079  Neighborhood 32: Almagro (6564.27 €/m2) - Dist...      sale
#
#        rent_price  is_rent_price_known  buy_price  buy_price_by_area  \
# 11079         901                False     195000               4149
#
#        is_buy_price_known       house_type_id  is_renewal_needed  \
# ...

# %%
my_df=df[['id','subtitle','sq_mt_built','n_rooms','n_bathrooms','rent_price','buy_price','buy_price_by_area']]

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21742 non-null  int64
#  1   subtitle           21742 non-null  object
#  2   sq_mt_built        21616 non-null  float64
#  3   n_rooms            21742 non-null  int64
#  4   n_bathrooms        21726 non-null  float64
#  5   rent_price         21742 non-null  int64
#  6   buy_price          21742 non-null  int64
#  7   buy_price_by_area  21742 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.3+ MB

# %%
my_df=my_df.rename(columns={'subtitle':'City'})

# %%
my_df['n_rooms'].describe()
# Out:
# count   21,742.00
# mean         3.01
# std          1.51
# min          0.00
# 25%          2.00
# 50%          3.00
# 75%          4.00
# max         24.00
# Name: n_rooms, dtype: float64

# %%
my_df.drop(my_df.index[df.n_rooms==0],axis=0,inplace=True)

# %%
my_df.n_bathrooms.describe()
# Out:
# count   21,298.00
# mean         2.11
# std          1.41
# min          1.00
# 25%          1.00
# 50%          2.00
# 75%          2.00
# max         16.00
# Name: n_bathrooms, dtype: float64

# %%
my_df.n_bathrooms.fillna(1,inplace=True)
my_df.n_bathrooms.replace(0,1,inplace=True)
# Out:
# C:\Users\mohaa\AppData\Local\Temp\ipykernel_17488\1947410948.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   my_df.n_bathrooms.fillna(1,inplace=True)
# C:\Users\mohaa\AppData\Local\Temp\ipykernel_17488\1947410948.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21303 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21303 non-null  int64
#  1   City               21303 non-null  object
#  2   sq_mt_built        21177 non-null  float64
#  3   n_rooms            21303 non-null  int64
#  4   n_bathrooms        21303 non-null  float64
#  5   rent_price         21303 non-null  int64
#  6   buy_price          21303 non-null  int64
#  7   buy_price_by_area  21303 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.5+ MB

# %%
my_df.n_bathrooms=my_df.n_bathrooms.astype(int)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21303 entries, 0 to 21741
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 21303 non-null  int64
#  1   City               21303 non-null  object
#  2   sq_mt_built        21177 non-null  float64
#  3   n_rooms            21303 non-null  int64
#  4   n_bathrooms        21303 non-null  int64
#  5   rent_price         21303 non-null  int64
#  6   buy_price          21303 non-null  int64
#  7   buy_price_by_area  21303 non-null  int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.5+ MB

# %%
my_df.dropna(subset='sq_mt_built',inplace=True)

# %%
my_df.sample(10)
# Out:
#           id                          City  sq_mt_built  n_rooms  n_bathrooms  \
# 12364   9378               Almagro, Madrid       208.00        4            3
# 17878   3864  Malasaña-Universidad, Madrid        66.00        1            1
# 5974   15768           Media Legua, Madrid        70.00        2            1
# 9418   12324          Montecarmelo, Madrid       132.00        2            2
# 18824   2918  Malasaña-Universidad, Madrid       153.00        4            2
# 5978   15764             Fontarrón, Madrid        78.00        3            1
# 15643   6099             Chamartín, Madrid       173.00        4            2
# 195    21547           Los Rosales, Madrid        59.00        2            1
# 7295   14447               Moncloa, Madrid       137.00        3            2
# 16957   4785         Puerta Bonita, Madrid        78.00        2            1
#
#        rent_price  buy_price  buy_price_by_area
# 12364        1059    1300000               6250
# ...

# %%
for value in my_df.rent_price.values:
    if value<0:
        my_df.rent_price=0

# %%
my_df[my_df.rent_price<0]
# Out:
# Empty DataFrame
# Columns: [id, City, sq_mt_built, n_rooms, n_bathrooms, rent_price, buy_price, buy_price_by_area]
# Index: []

# %%
my_df['district']=my_df.City.str.split(',',expand=True)[0]

# %%
my_df=my_df[['id','district' , 'sq_mt_built', 'n_rooms', 'n_bathrooms', 
    'buy_price', 'buy_price_by_area']]

# %%
#my_df.to_excel("after_cleaning.xlsx", sheet_name="cleaned data", index=False)

# %%
fig = px.box(my_df, x="district", y="buy_price")  
fig.show()

# %%
fig = px.box(my_df, x="buy_price",title='For buy price')  
fig.show()

# %%
fig = px.box(my_df, x="buy_price_by_area")  
fig.show()

# %%
fig = px.box(my_df, x="district", y="buy_price_by_area")  
fig.show()

# %%
my_df.sample()
# Out:
#           id    district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 11589  10153  Gaztambide       151.00        4            3     600000
#
#        buy_price_by_area
# 11589               3974

# %%
corr=my_df[['sq_mt_built','n_rooms','n_bathrooms']]
sns.pairplot(corr,kind='reg')
plt.tight_layout()

# %%
sns.heatmap(corr.corr(),annot=True)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
mean_price=my_df.groupby('district')['buy_price'].mean().round(2).sort_values(ascending=False)
mean_price.head(10).plot(kind='bar',xlabel='district',ylabel='buy_price')
# Out:
# <Axes: xlabel='district', ylabel='buy_price'>

# %%
my_df.sample()
# Out:
#          id       district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 3073  18669  Valdeacederas        43.00        1            1     167000
#
#       buy_price_by_area
# 3073               3884

# %%
mean_price=my_df.groupby('district')['buy_price_by_area'].mean().round(2).sort_values(ascending=False)
mean_price.head(10).plot(kind='bar',xlabel='district',ylabel='buy_price_by_area')
# Out:
# <Axes: xlabel='district', ylabel='buy_price_by_area'>

# %%
import statsmodels.api as sm

reco = my_df.query('district=="Recoletos"').copy()
X = sm.add_constant(reco['sq_mt_built'])
y = reco['buy_price']

lm = sm.OLS(y, X)
result = lm.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     555.1
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):           5.30e-45
# Time:                        13:08:30   Log-Likelihood:                -1654.1
# No. Observations:                 113   AIC:                             3312.
# Df Residuals:                     111   BIC:                             3318.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.342e+04   1.07e+05     -0.406      0.686   -2.55e+05    1.69e+05
# ...

# %%
# البواقي والتوقعات
residuals = result.resid
fitted = result.fittedvalues

# 1. Scatterplot: البواقي ضد القيم المتوقعة
plt.figure(figsize=(6,4))
plt.scatter(fitted, residuals, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.show()

# 2. هيستوجرام للبواقي
plt.figure(figsize=(6,4))
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.title("Distribution of Residuals")
plt.show()

# 3. QQ-Plot للتوزيع الطبيعي
sm.qqplot(residuals, line='45')
plt.title("QQ-Plot")
plt.show()

# %%
reco = my_df.query('district == "Recoletos"').copy()

X = sm.add_constant(reco[['sq_mt_built','n_rooms','n_bathrooms']])

y = reco['buy_price']

# بناء الموديل
lm = sm.OLS(y, X)
result = lm.fit()

print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     245.2
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):           2.69e-48
# Time:                        13:08:31   Log-Likelihood:                -1639.7
# No. Observations:                 113   AIC:                             3287.
# Df Residuals:                     109   BIC:                             3298.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.068e+05   1.29e+05      0.828      0.409   -1.49e+05    3.62e+05
# ...

# %%
my_df.sample()
# Out:
#           id                        district  sq_mt_built  n_rooms  \
# 10757  10985  Virgen del Cortijo - Manoteras       117.00        2
#
#        n_bathrooms  buy_price  buy_price_by_area
# 10757            2     450000               3846

# %%
df_dummy=my_df.query('district in ("Recoletos","Castellana","Trafalgar")')
df_dummy.sample(10)
# Out:
#           id    district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 12194   9548   Trafalgar        63.00        1            1     295000
# 12210   9532   Trafalgar        65.00        1            1     460000
# 11768   9974   Trafalgar        33.00        2            1     150000
# 19329   2413  Castellana        80.00        2            2     485000
# 19503   2239   Recoletos       390.00        5            4    2290000
# 11361  10381   Trafalgar       132.00        3            2    1200000
# 12274   9468   Trafalgar        64.00        1            1     485000
# 19943   1799   Recoletos       221.00        4            4    1700000
# 19543   2199  Castellana       397.00        9            3    2000000
# 20076   1666   Recoletos       156.00        3            3    1250000
#
#        buy_price_by_area
# 12194               4683
# 12210               7077
# 11768               4545
# 19329               6062
# 19503               5872
# 11361               9091
# ...

# %%
my_df.district.unique()
# Out:
# array(['San Cristóbal', 'Los Ángeles', 'San Andrés', 'Los Rosales',
#        'Villaverde', 'Butarque', 'Vicálvaro', 'Ambroz',
#        'Casco Histórico de Vicálvaro', 'El Cañaveral - Los Berrocales',
#        'Valdebernardo - Valderribas', 'Casco Histórico de Vallecas',
#        'Ensanche de Vallecas - La Gavia', 'Villa de Vallecas',
#        'Santa Eugenia', 'Orcasitas', 'Usera', 'San Fermín', 'Pradolongo',
#        'Zofío', 'Almendrales', 'Moscardó', '12 de Octubre-Orcasur',
#        'Valdeacederas', 'Tetuán', 'Berruguete', 'Cuatro Caminos',
#        'Cuzco-Castillejos', 'Bellas Vistas', 'Ventilla-Almenara',
#        'Retiro', 'Adelfas', 'Ibiza', 'Pacífico', 'Niño Jesús',
#        'Jerónimos', 'Estrella', 'Puente de Vallecas', 'Palomeras Bajas',
#        'San Diego', 'Palomeras sureste', 'Entrevías', 'Numancia',
#        'Portazgo', 'Aravaca', 'Argüelles', 'Moncloa',
#        'Ciudad Universitaria', 'Valdezarza', 'Fontarrón', 'Moratalaz',
# ...

# %%
pd.get_dummies(df_dummy.district)
# Out:
#        Castellana  Recoletos  Trafalgar
# 10937       False      False       True
# 11000       False      False       True
# 11001       False      False       True
# 11010       False      False       True
# 11042       False      False       True
# 11061       False      False       True
# 11062       False      False       True
# 11065       False      False       True
# 11099       False      False       True
# 11103       False      False       True
# 11173       False      False       True
# 11177       False      False       True
# 11194       False      False       True
# 11208       False      False       True
# 11212       False      False       True
# 11219       False      False       True
# 11242       False      False       True
# 11259       False      False       True
# 11307       False      False       True
# 11308       False      False       True
# 11309       False      False       True
# 11310       False      False       True
# ...

# %%
df_dummy[['cast','reco','traf']]=pd.get_dummies(df_dummy.district,dtype='int')
df_dummy.sample(10)
# Out:
# C:\Users\mohaa\AppData\Local\Temp\ipykernel_17488\4251345577.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           id    district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 11687  10055   Trafalgar        67.00        2            2     550000
# 12181   9561   Trafalgar       107.00        2            2     750000
# 19543   2199  Castellana       397.00        9            3    2000000
# 19333   2409  Castellana       416.00        5            4    2500000
# 20082   1660   Recoletos       247.00        4            2    1700000
# 19241   2501   Recoletos        75.00        2            2     750000
# 11855   9887   Trafalgar       107.00        3            2     695000
# ...

# %%
df_dummy['intercept']=1
lm=sm.OLS(df_dummy.buy_price,df_dummy[['intercept','cast','traf']])
my_result=lm.fit()
my_result.summary()
# Out:
# C:\Users\mohaa\AppData\Local\Temp\ipykernel_17488\2046972481.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              buy_price   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     114.3
# Date:                Sun, 14 Sep 2025   Prob (F-statistic):           5.20e-40
# Time:                        13:43:07   Log-Likelihood:                -6095.1
# No. Observations:                 404   AIC:                         1.220e+04
# ...

# %%
df_dummy.sample()
# Out:
#          id   district  sq_mt_built  n_rooms  n_bathrooms  buy_price  \
# 12274  9468  Trafalgar        64.00        1            1     485000
#
#        buy_price_by_area  cast  traf  reco
# 12274               7578     0     1     0
